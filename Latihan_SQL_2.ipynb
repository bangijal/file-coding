# %% [markdown]
# # Latihan_MYSQL_2

# %% [markdown]
# Nama : RIzal Imran Rusyadi (kelas : BD - B)

# %% [markdown]
# ## One to many relationship

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ### 1. Report the account representative for each customer.

# %%
run("""
SELECT 
    customerNumber, 
    customerName, 
    salesRepEmployeeNumber    
FROM
    customers t1
        INNER JOIN
    employees t2 ON t1.salesRepEmployeeNumber = t2.employeeNumber
""")
# Out:
#     customerNumber                       customerName  salesRepEmployeeNumber
# 0              148            Dragon Souveniers, Ltd.                    1621
# 1              177               Osaka Souveniers Co.                    1621
# 2              211        King Kong Collectables, Co.                    1621
# 3              385                    Cruz & Sons Co.                    1621
# 4              398            Tokyo Collectables, Ltd                    1621
# 5              114         Australian Collectors, Co.                    1611
# 6              276            Anna's Decorations, Ltd                    1611
# 7              282          Souveniers And Things Co.                    1611
# 8              333        Australian Gift Network, Co                    1611
# 9              471       Australian Collectables, Ltd                    1611
# 10             166                   Handji Gifts& Co                    1612
# ...

# %% [markdown]
# ### 2. Report total payments for Atelier graphique.

# %%
run("""
SELECT 
    customerName,
    SUM(amount) AS Total_payments
FROM
    customers t1
    INNER JOIN
    payments t2 
        ON t1.customerNumber = t2.customerNumber
WHERE
    customerName='Atelier graphique'
""")
# Out:
#         customerName  Total_payments
# 0  Atelier graphique        22314.36

# %% [markdown]
# ### 3. Report the total payments by date

# %%
# run("""
# SELECT 
#     paymentDate,
#     SUM(amount) AS Total
# FROM
#     payments
# GROUP BY paymentDate
# """)
run("""
    SELECT paymentDate, SUM(amount) AS Total_by_Date FROM payments GROUP BY paymentDate """)
# Out:
#     paymentDate  Total_by_Date
# 0    2003-01-16       10223.83
# 1    2003-01-28       10549.01
# 2    2003-01-30        5494.78
# 3    2003-02-16       50218.95
# 4    2003-02-20       53959.21
# 5    2003-02-25       40206.20
# 6    2003-03-02       52151.81
# 7    2003-03-09       51001.22
# 8    2003-03-12       22292.62
# 9    2003-03-20       25833.14
# 10   2003-03-27       48425.69
# 11   2003-04-09       24212.79
# 12   2003-04-11       11044.30
# 13   2003-04-16       21665.98
# 14   2003-04-19        1627.56
# 15   2003-04-20       33383.14
# 16   2003-04-22       44380.15
# 17   2003-05-09        3101.40
# 18   2003-05-12       35826.33
# 19   2003-05-20       45864.03
# 20   2003-05-21       16700.47
# 21   2003-05-25       50824.66
# 22   2003-05-31        7565.08
# 23   2003-06-05       14571.44
# 24   2003-06-06       32641.98
# 25   2003-06-13       57131.92
# 26   2003-06-18       58841.35
# 27   2003-06-25       17032.29
# 28   2003-07-05        2880.00
# ...

# %% [markdown]
# ### 4. Report the products that have not been sold.

# %%
run("""
SELECT 
    productName,
    quantityOrdered
FROM
    orderdetails tb1
    RIGHT JOIN
    products tb2 
        ON tb1.productCode = tb2.productCode
WHERE 
    tb1.orderNumber IS NULL
""")
# Out:
#          productName quantityOrdered
# 0  1985 Toyota Supra            None

# %% [markdown]
# ### 5. List the amount paid by each customer.

# %%
run("""
SELECT 
    customerName,
    SUM(amount) AS paid
FROM
    customers t1
    
    INNER JOIN
    
    payments t2 
        ON t1.customerNumber = t2.customerNumber
GROUP BY customerName
""")
# Out:
#                           customerName       paid
# 0                         Alpha Cognac   60483.36
# 1                   Amica Models & Co.   82223.23
# 2              Anna's Decorations, Ltd  137034.22
# 3                    Atelier graphique   22314.36
# 4         Australian Collectables, Ltd   44920.76
# 5           Australian Collectors, Co.  180585.07
# 6          Australian Gift Network, Co   55190.16
# 7                 Auto Associés & Cie.   58876.41
# 8                    Auto Canal+ Petit   86436.97
# 9              Auto-Moto Classics Inc.   21554.26
# 10                      AV Stores, Co.  148410.09
# 11                  Baane Mini Imports  104224.79
# 12  Bavarian Collectables Imports, Co.   31310.09
# 13                Blauer See Auto, Co.   75937.76
# 14                   Boards & Toys Co.    7918.60
# 15                         CAF Imports   46751.14
# 16          Cambridge Collectables Co.   32198.69
# 17      Canadian Gift Exchange Network   70122.19
# ...

# %% [markdown]
# ### 6. How many orders have been placed by Herkku Gifts?

# %%
run("""
SELECT 
    customerName,
    SUM(orderNumber) AS number_of_Order
FROM
    customers t1
    INNER JOIN
    orders t2 
        ON t1.customerNumber = t2.customerNumber
WHERE
    customerName='Herkku Gifts'
""")
# Out:
#    customerName  number_of_Order
# 0  Herkku Gifts          30658.0

# %% [markdown]
# ### 7. Who are the employees in Boston?

# %%
run("""
SELECT 
    firstName AS employeer,
    city
FROM
    employees t1
    INNER JOIN
    offices t2 
        ON t1.officeCode = t2.officeCode
WHERE
    city='Boston'
""")
# Out:
#   employeer    city
# 0     Julie  Boston
# 1     Steve  Boston

# %% [markdown]
# ### 8. Report those payments greater than \$100,000. Sort the report so the customer who made the highest payment appears first.

# %%
run("""
SELECT 
    customerName AS Customer,
    amount AS Payments
FROM
    customers t1
    INNER JOIN
    payments t2 
        ON t1.customerNumber = t2.customerNumber
WHERE amount>100000
ORDER BY amount DESC
""")
# Out:
#                        Customer   Payments
# 0        Euro+ Shopping Channel  120166.58
# 1        Euro+ Shopping Channel  116208.40
# 2  Mini Gifts Distributors Ltd.  111654.40
# 3       Dragon Souveniers, Ltd.  105743.00
# 4  Mini Gifts Distributors Ltd.  101244.59

# %% [markdown]
# ### 9. List the value of 'On Hold' orders.

# %%
run("SELECT * FROM orders WHERE status = 'On Hold'")
# Out:
#    orderNumber   orderDate requiredDate shippedDate   status  \
# 0        10334  2004-11-19   2004-11-28        None  On Hold
# 1        10401  2005-04-03   2005-04-14        None  On Hold
# 2        10407  2005-04-22   2005-05-04        None  On Hold
# 3        10414  2005-05-06   2005-05-13        None  On Hold
#
#                                             comments  customerNumber
# 0  The outstaniding balance for this customer exc...             144
# 1  Customer credit limit exceeded. Will ship when...             328
# 2  Customer credit limit exceeded. Will ship when...             450
# 3  Customer credit limit exceeded. Will ship when...             362

# %% [markdown]
# ### 10. Report the number of orders 'On Hold' for each customer.

# %%
run("""
SELECT 
    customerName,
    COUNT(status) AS On_Hold_STATUS
FROM
    customers t1
    INNER JOIN
    orders t2 
        ON t1.customerNumber = t2.customerNumber
WHERE 
    status='On Hold'
GROUP BY 
    customerName
""")
# Out:
#                 customerName  On_Hold_STATUS
# 0          Gifts4AllAges.com               1
# 1    Tekni Collectables Inc.               1
# 2  The Sharp Gifts Warehouse               1
# 3   Volvo Model Replicas, Co               1

# %% [markdown]
# ## Many to many relationship

# %% [markdown]
# ### 1. List products sold by order date.

# %%
run("""
SELECT 
    (productName) AS Product_Name,    
    orderDate
FROM
    ((orderdetails t1
    INNER JOIN
    orders t2 
        ON t1.orderNumber = t2.orderNumber)
    INNER JOIN
    products t3 
        ON t1.productCode = t3.productCode)  
ORDER BY orderDate 
""")
# Out:
#                                      Product_Name   orderDate
# 0                        1917 Grand Touring Sedan  2003-01-06
# 1                              1911 Ford Town Car  2003-01-06
# 2             1932 Alfa Romeo 8C2300 Spider Sport  2003-01-06
# 3                1936 Mercedes Benz 500k Roadster  2003-01-06
# 4                       1932 Model A Ford J-Coupe  2003-01-09
# 5                          1928 Mercedes-Benz SSK  2003-01-09
# 6                     1939 Chevrolet Deluxe Coupe  2003-01-09
# 7       1938 Cadillac V-16 Presidential Limousine  2003-01-09
# 8                            1937 Lincoln Berline  2003-01-10
# 9        1936 Mercedes-Benz 500K Special Roadster  2003-01-10
# 10                       1952 Alpine Renault 1300  2003-01-29
# 11                         1962 LanciaA Delta 16V  2003-01-29
# 12                                 1958 Setra Bus  2003-01-29
# 13                         1940 Ford Pickup Truck  2003-01-29
# ...

# %% [markdown]
# ### 2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.

# %%
run("""
SELECT 
    productName,
    orderDate
FROM
    ((orderdetails t1
    INNER JOIN
    orders t2 
        ON t1.orderNumber = t2.orderNumber)
    INNER JOIN
    products t3 
        ON t1.productCode = t3.productCode)  
WHERE 
    productName='1940 Ford Pickup Truck'
ORDER BY orderDate ASC 
""")
# Out:
#                productName   orderDate
# 0   1940 Ford Pickup Truck  2003-01-29
# 1   1940 Ford Pickup Truck  2003-03-26
# 2   1940 Ford Pickup Truck  2003-05-28
# 3   1940 Ford Pickup Truck  2003-07-24
# 4   1940 Ford Pickup Truck  2003-09-19
# 5   1940 Ford Pickup Truck  2003-10-21
# 6   1940 Ford Pickup Truck  2003-11-06
# 7   1940 Ford Pickup Truck  2003-11-13
# 8   1940 Ford Pickup Truck  2003-11-25
# 9   1940 Ford Pickup Truck  2003-12-05
# 10  1940 Ford Pickup Truck  2004-01-29
# 11  1940 Ford Pickup Truck  2004-03-10
# 12  1940 Ford Pickup Truck  2004-05-04
# 13  1940 Ford Pickup Truck  2004-06-15
# 14  1940 Ford Pickup Truck  2004-07-19
# 15  1940 Ford Pickup Truck  2004-08-17
# 16  1940 Ford Pickup Truck  2004-09-08
# 17  1940 Ford Pickup Truck  2004-10-11
# 18  1940 Ford Pickup Truck  2004-10-21
# 19  1940 Ford Pickup Truck  2004-11-04
# 20  1940 Ford Pickup Truck  2004-11-18
# 21  1940 Ford Pickup Truck  2004-11-29
# 22  1940 Ford Pickup Truck  2004-12-10
# ...

# %% [markdown]
# ### 3. List the names of customers and their corresponding order number where a particular order from that customer has a value greater than $25,000?

# %%
run("""
SELECT 
    customerName,
    orderNumber,
    amount
FROM
    ((customers t1
    INNER JOIN
    orders t2 
        ON t1.customerNumber = t2.customerNumber)
    INNER JOIN
    payments t3 
        ON t1.customerNumber = t3.customerNumber)  
 WHERE amount>25000
""")
# Out:
#                      customerName  orderNumber    amount
# 0              Signal Gift Stores        10124  32641.98
# 1              Signal Gift Stores        10278  32641.98
# 2              Signal Gift Stores        10346  32641.98
# 3              Signal Gift Stores        10124  33347.88
# 4              Signal Gift Stores        10278  33347.88
# 5              Signal Gift Stores        10346  33347.88
# 6      Australian Collectors, Co.        10120  45864.03
# 7      Australian Collectors, Co.        10125  45864.03
# 8      Australian Collectors, Co.        10223  45864.03
# 9      Australian Collectors, Co.        10342  45864.03
# 10     Australian Collectors, Co.        10347  45864.03
# 11     Australian Collectors, Co.        10120  82261.22
# 12     Australian Collectors, Co.        10125  82261.22
# 13     Australian Collectors, Co.        10223  82261.22
# 14     Australian Collectors, Co.        10342  82261.22
# ...

# %% [markdown]
# ### 4. Are there any products that appear on all orders?

# %%
run("""
SELECT 
    productName,
    COUNT(t1.orderNumber) AS number_of_order
FROM
    ((orderdetails t1
    INNER JOIN
    products t2 
        ON t1.productCode = t2.productCode)
    INNER JOIN
    orders t3 
        ON t1.orderNumber = t3.orderNumber)  
GROUP BY productName      
ORDER BY number_of_order
""")
# Out:
#                                  productName  number_of_order
# 0                      1957 Ford Thunderbird               24
# 1                          1952 Citroen-15CV               24
# 2             1948 Porsche Type 356 Roadster               25
# 3               1999 Indy 500 Monte Carlo SS               25
# 4                         1949 Jaguar XK 120               25
# 5                  1969 Chevrolet Camaro Z28               25
# 6                        2002 Chevy Corvette               25
# 7        1932 Alfa Romeo 8C2300 Spider Sport               25
# 8                   1917 Grand Touring Sedan               25
# 9                 1970 Chevy Chevelle SS 454               25
# 10                 1966 Shelby Cobra 427 S/C               25
# 11          1936 Mercedes Benz 500k Roadster               25
# 12                     1965 Aston Martin DB5               25
# 13                        1911 Ford Town Car               25
# ...

# %% [markdown]
# ### 5. List the names of products sold at less than 80% of the MSRP.

# %%
run("""
SELECT 
    productName,
    priceEach,
    MSRP
    
FROM
    products t1
    INNER JOIN
    orderdetails t2 
        ON t1.productCode = t2.productCode
WHERE
    priceEach<(0.8*MSRP)
ORDER BY priceEach
""")
# Out:
#                                     productName  priceEach    MSRP
# 0                   1939 Chevrolet Deluxe Coupe      26.55   33.19
# 1                   1939 Chevrolet Deluxe Coupe      26.55   33.19
# 2              1936 Mercedes Benz 500k Roadster      32.82   41.03
# 3              1936 Mercedes Benz 500k Roadster      32.82   41.03
# 4              1936 Mercedes Benz 500k Roadster      32.82   41.03
# 5                  1930 Buick Marquette Phaeton      34.91   43.64
# 6                1962 City of Detroit Streetcar      46.86   58.58
# 7                            1911 Ford Town Car      48.43   60.54
# 8                     1971 Alpine Renault 1600s      48.98   61.23
# 9        1950's Chicago Surface Lines Streetcar      49.71   62.14
# 10  1996 Peterbilt 379 Stake Bed with Outrigger      51.71   64.64
# 11                     Corsair F4U ( Bird Cage)      54.59   68.24
# 12                    The USS Constitution Ship      57.82   72.28
# ...

# %% [markdown]
# ### 6. Reports those products that have been sold with a markup of 100% or more (i.e., the priceEach is at least twice the buyPrice)

# %%
run("""
SELECT 
    orderNUmber,
    productName,    
    buyPrice,
    priceEach
FROM
    products t1
    INNER JOIN
    orderdetails t2 
        ON t1.productCode = t2.productCode
WHERE
    priceEach>(2*buyPrice)
ORDER BY priceEach
""")
# Out:
#      orderNUmber                           productName  buyPrice  priceEach
# 0          10141   1958 Chevy Corvette Limited Edition     15.91      32.18
# 1          10175   1958 Chevy Corvette Limited Edition     15.91      32.18
# 2          10181               1982 Lamborghini Diablo     16.24      32.85
# 3          10412   1958 Chevy Corvette Limited Edition     15.91      32.88
# 4          10335   1958 Chevy Corvette Limited Edition     15.91      32.88
# 5          10147               1982 Lamborghini Diablo     16.24      33.23
# 6          10192               1982 Lamborghini Diablo     16.24      33.23
# 7          10203               1982 Lamborghini Diablo     16.24      33.23
# 8          10310               1982 Lamborghini Diablo     16.24      33.23
# 9          10383   1958 Chevy Corvette Limited Edition     15.91      33.24
# 10         10358   1958 Chevy Corvette Limited Edition     15.91      33.59
# ...

# %% [markdown]
# ### 7. List the products ordered on a Monday.

# %%
run("""
SELECT 
    productName,
    DAYNAME(orderDate) AS Day,
    orderDate
FROM
    ((orderdetails t1
    INNER JOIN
    products t2 
        ON t1.productCode = t2.productCode)
    INNER JOIN
    orders t3 
        ON t1.orderNumber = t3.orderNumber)  
WHERE 
    DAYNAME(orderDate)='Monday'
""")
# Out:
#                                productName     Day   orderDate
# 0    1969 Harley Davidson Ultimate Chopper  Monday  2003-02-24
# 1    1969 Harley Davidson Ultimate Chopper  Monday  2003-08-25
# 2    1969 Harley Davidson Ultimate Chopper  Monday  2003-12-01
# 3    1969 Harley Davidson Ultimate Chopper  Monday  2004-04-05
# 4    1969 Harley Davidson Ultimate Chopper  Monday  2004-06-28
# 5    1969 Harley Davidson Ultimate Chopper  Monday  2004-11-15
# 6                 1952 Alpine Renault 1300  Monday  2003-03-24
# 7                 1952 Alpine Renault 1300  Monday  2003-10-20
# 8                 1952 Alpine Renault 1300  Monday  2004-07-19
# 9                 1952 Alpine Renault 1300  Monday  2004-10-11
# 10                1952 Alpine Renault 1300  Monday  2004-11-29
# 11                   1996 Moto Guzzi 1100i  Monday  2003-02-24
# 12                   1996 Moto Guzzi 1100i  Monday  2003-08-25
# 13                   1996 Moto Guzzi 1100i  Monday  2003-12-01
# ...

# %% [markdown]
# ### 8. What is the quantity on hand for products listed on 'On Hold' orders?

# %%
run("""
SELECT 
    productName,
    status
FROM
    ((orderdetails t1
    INNER JOIN
    products t2 
        ON t1.productCode = t2.productCode)
    INNER JOIN
    orders t3 
        ON t1.orderNumber = t3.orderNumber)  
WHERE 
    status='On Hold'
""")
# Out:
#                             productName   status
# 0                   1972 Alfa Romeo GTA  On Hold
# 1                1962 LanciaA Delta 16V  On Hold
# 2                 1965 Aston Martin DB5  On Hold
# 3              1917 Grand Touring Sedan  On Hold
# 4                    1911 Ford Town Car  On Hold
# 5                1964 Mercedes Tour Bus  On Hold
# 6                 1926 Ford Fire Engine  On Hold
# 7                        P-51-D Mustang  On Hold
# 8          1999 Indy 500 Monte Carlo SS  On Hold
# 9                1999 Yamaha Speed Boat  On Hold
# 10                    1903 Ford Model A  On Hold
# 11          1992 Ferrari 360 Spider red  On Hold
# 12             Collectable Wooden Train  On Hold
# 13  1932 Alfa Romeo 8C2300 Spider Sport  On Hold
# 14                  1904 Buick Runabout  On Hold
# 15                     1940s Ford truck  On Hold
# 16                1957 Ford Thunderbird  On Hold
# 17           1970 Chevy Chevelle SS 454  On Hold
# ...

# %%
run("""
SELECT 
    COUNT(productName) AS count_Produk_OnHold
FROM
    ((orderdetails t1
    INNER JOIN
    products t2 
        ON t1.productCode = t2.productCode)
    INNER JOIN
    orders t3 
        ON t1.orderNumber = t3.orderNumber)  
WHERE 
    status='On Hold'
""")
# Out:
#    count_Produk_OnHold
# 0                   44
